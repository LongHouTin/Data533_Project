# %% [markdown]
# Note:
# For this specific package I can not do the SetUpClass and TearDownClass like what the lecturer did in class because of the problem focused. The primary function of the package is to obtain data from online and do some basic visualization of some important variables that I watch everyday. We can check the modules working properly and return the corect values/graph, but even the setup and tearDown to initialize the values is problemetic because of the functions defined and tested.

# %%
import unittest
from fed.calculate.fmath import netPurchaseChange
from fed.calculate.fmath import netPurchase

class TestFmath1(unittest.TestCase):
    
    def setUp(self):
        print("this is setUp")
        
    def tearDown(self):
        print("this is tearDown")
    
    
    
    def test_netPurchaseChange(self):
        self.assertEqual(netPurchaseChange("2019-11-22"),0.0826)
        self.assertEqual(netPurchaseChange("2019-11-25"),-0.1501)
        self.assertEqual(netPurchaseChange("2019-11-26"),0.062)
        self.assertEqual(netPurchaseChange("2019-11-27"),0.2158)
        self.assertEqual(netPurchaseChange("2019-10-31"),0.2119)
        self.assertEqual(netPurchaseChange("2019-10-28"),-0.0098)
    
    def test_netPurchase(self):
        self.assertEqual(netPurchase("2019-11-22"),80.225)
        self.assertEqual(netPurchase("2019-11-25"),68.5)
        self.assertEqual(netPurchase("2019-11-26"),70.545)
        self.assertEqual(netPurchase("2019-11-27"),87.7)
        self.assertEqual(netPurchase("2019-10-31"),69.682)
        self.assertEqual(netPurchase("2019-10-28"),76.547)

unittest.main(argv=[''],verbosity=2,exit=False)
# Out:
# test_netPurchase (__main__.TestFmath1) ...
# this is setUp
# ok
# test_netPurchaseChange (__main__.TestFmath1) ...
# this is tearDown
# this is setUp
# this is tearDown
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 3.517s
#
# OK

# %%
import unittest
from fed.calculate.fmath import nasdaq
from fed.calculate.fmath import vix

class TestFmath2(unittest.TestCase):
    def setUp(self):
        print("this is setUp")
        
    def tearDown(self):
        print("this is tearDown")
    
    
    
    def test_nasdaq(self):
        self.assertEqual(nasdaq("2019-11-27"),8705.17)
        self.assertEqual(nasdaq("2019-11-15"),8540.82)
        self.assertEqual(nasdaq("2019-11-06"),8410.62)
        self.assertEqual(nasdaq("2019-11-25"),8632.48)
        self.assertEqual(nasdaq("2019-11-08"),8475.31)
        
    def test_vix(self):
        self.assertEqual(vix("2019-11-27"),11.75)
        self.assertEqual(vix("2019-11-11"),12.69)
        self.assertEqual(vix("2019-11-26"),11.54)
        self.assertEqual(vix("2019-11-29"),12.62)
        self.assertEqual(vix("2019-12-02"),14.91)

unittest.main(argv=[''],verbosity=2,exit=False)
# Out:
# test_netPurchase (__main__.TestFmath1) ...
# this is setUp
# ok
# test_netPurchaseChange (__main__.TestFmath1) ...
# this is tearDown
# this is setUp
# ok
# test_nasdaq (__main__.TestFmath2) ...
# this is tearDown
# this is setUp
# ok
# test_vix (__main__.TestFmath2) ...
# this is tearDown
# this is setUp
# this is tearDown
# ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 6.304s
#
# OK

# %%
import unittest
from fed.draw.visualize import linechart,barchart30days,barchartyrs
class TestVisualize(unittest.TestCase):
    
    
    def setUp(self):
        print("this is setUp")
        
    def tearDown(self):
        print("this is tearDown")
        
    def test_linechart(self):
        self.assertEqual(linechart(),None)
        
        
    def test_barchart30days(self):
        self.assertEqual(barchart30days(),None)

        
    def test_barchartyrs(self):
        self.assertEqual(barchartyrs(),None)

        

unittest.main(argv=[''],verbosity=2,exit=False)
# Out:
# test_netPurchase (__main__.TestFmath1) ...
# this is setUp
# ok
# test_netPurchaseChange (__main__.TestFmath1) ...
# this is tearDown
# this is setUp
# ok
# test_nasdaq (__main__.TestFmath2) ...
# this is tearDown
# this is setUp
# ok
# test_vix (__main__.TestFmath2) ...
# this is tearDown
# this is setUp
# ok
# test_barchart30days (__main__.TestVisualize) ...
# this is tearDown
# this is setUp
# C:\Users\DELL\Anaconda3\lib\site-packages\pygal\_compat.py:23: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable
# ok
# test_barchartyrs (__main__.TestVisualize) ...
# this is tearDown
# this is setUp
# ok
# test_linechart (__main__.TestVisualize) ...
# this is tearDown
# this is setUp
# this is tearDown
# ok
#
# ----------------------------------------------------------------------
# Ran 7 tests in 9.719s
#
# OK

# %%
import unittest
from fed.crawl.crawl import webcrawl
class TestCrawl(unittest.TestCase):
    
    def setUp(self):
        print("this is setUp")
        
    def tearDown(self):
        print("this is tearDown")
    
    def test_webcrawl(self):
        self.assertEqual(webcrawl(),None)  # test should be carried out with internet connection otherwise failed

unittest.main(argv=[''],verbosity=2,exit=False)
# Out:
# test_webcrawl (__main__.TestCrawl) ...
# this is setUp
# C:\Users\DELL\Anaconda3\lib\site-packages\html5lib\_trie\_base.py:3: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping
# C:\Users\DELL\fed\crawl\crawl.py:23: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 23 of the file C:\Users\DELL\fed\crawl\crawl.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup=bs(ct)
# ok
# test_netPurchase (__main__.TestFmath1) ...
# successfully crawling data from Fed! The most recent date is:2019-12-03
# ...
