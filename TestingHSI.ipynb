# %%
import fed.HSI.instant as it

# %%
it.instant().indices()
# Out:
#                                   Previous       Open    Instant
# Hang_Seng_Index                  26,346.49  26,475.34  26,444.72
# Finance_Sub-index                37,159.74  37,272.02  37,280.61
# Utilities_Sub-index              55,172.08  55,181.14  54,935.01
# Properties_Sub-index             37,311.18  37,538.61  37,596.94
# Commerce_and_Industry_Sub-index  14,781.30  14,897.09  14,844.70

# %%
it.instant().stocks()
# Out:
#         Code      Name Last_price  Market_Cap    P/E    P/B   Yield  \
# 1   00005.HK      匯豐控股     58.400  12,052.37億  11.83   0.82   6.84%
# 2   00011.HK      恆生銀行    159.900   3,057.04億  12.81   1.89   4.69%
# 3   00388.HK     香港交易所    247.600   3,122.73億  33.01   7.60   2.71%
# 4   00939.HK      建設銀行      6.230  14,978.00億   5.47   0.69   5.59%
# 5   01299.HK      友邦保險     78.900   9,538.06億  38.74   3.12   1.57%
# 6   01398.HK      工商銀行      5.560   4,825.75億   5.96   0.75   5.13%
# 7   02318.HK      中國平安     89.550   6,669.31億  13.07   2.58   2.19%
# 8   02388.HK      中銀香港     26.600   2,812.36億   8.79   1.09   5.52%
# 9   02628.HK      中國人壽     19.880   1,479.31億  44.77   1.55   0.92%
# 10  03328.HK      交通銀行      5.130   1,796.11億   4.69   0.48   6.66%
# 11  03988.HK      中國銀行      3.130   2,617.38億   4.66   0.50   6.69%
# 12  00002.HK      中電控股     79.850   2,017.37億  14.90   1.85   3.78%
# 13  00003.HK    香港中華煤氣     14.900   2,521.83億  27.09   4.04   2.14%
# ...

# %%
it.useless("F").indices()
# Out:
# Previous    37,159.74
# Open        37,272.02
# Instant     37,280.61
# Name: Finance_Sub-index, dtype: object

# %%
it.useless("F").stocks()
# Out:
#         Code   Name Last_price  Market_Cap    P/E   P/B  Yield   Sector
# 1   00005.HK   匯豐控股     58.400  12,052.37億  11.83  0.82  6.84%  Finance
# 2   00011.HK   恆生銀行    159.900   3,057.04億  12.81  1.89  4.69%  Finance
# 3   00388.HK  香港交易所    247.600   3,122.73億  33.01  7.60  2.71%  Finance
# 4   00939.HK   建設銀行      6.230  14,978.00億   5.47  0.69  5.59%  Finance
# 5   01299.HK   友邦保險     78.900   9,538.06億  38.74  3.12  1.57%  Finance
# 6   01398.HK   工商銀行      5.560   4,825.75億   5.96  0.75  5.13%  Finance
# 7   02318.HK   中國平安     89.550   6,669.31億  13.07  2.58  2.19%  Finance
# 8   02388.HK   中銀香港     26.600   2,812.36億   8.79  1.09  5.52%  Finance
# 9   02628.HK   中國人壽     19.880   1,479.31億  44.77  1.55  0.92%  Finance
# 10  03328.HK   交通銀行      5.130   1,796.11億   4.69  0.48  6.66%  Finance
# 11  03988.HK   中國銀行      3.130   2,617.38億   4.66  0.50  6.69%  Finance

# %%
it.useless("U").indices()
# Out:
# Previous    55,172.08
# Open        55,181.14
# Instant     54,935.01
# Name: Utilities_Sub-index, dtype: object

# %%
it.useless("U").stocks()
# Out:
#         Code    Name Last_price Market_Cap    P/E   P/B  Yield     Sector
# 12  00002.HK    中電控股     79.850  2,017.37億  14.90  1.85  3.78%  Utilities
# 13  00003.HK  香港中華煤氣     14.900  2,521.83億  27.09  4.04  2.14%  Utilities
# 14  00006.HK    電能實業     54.450  1,162.11億  15.21  1.39  5.14%  Utilities
# 15  01038.HK  長江基建集團     53.000  1,404.86億  12.80  1.31  4.59%  Utilities

# %%
it.useless("P").indices()
# Out:
# Previous    37,311.18
# Open        37,538.61
# Instant     37,596.94
# Name: Properties_Sub-index, dtype: object

# %%
it.useless("P").stocks()
# Out:
#         Code    Name Last_price Market_Cap    P/E   P/B  Yield      Sector
# 16  00012.HK    恆基地產     37.550  1,817.94億   5.83  0.58  4.36%  Properties
# 17  00016.HK   新鴻基地產    113.300  3,283.19億   7.31  0.58  4.37%  Properties
# 18  00017.HK   新世界發展     10.160  1,039.24億   5.71  0.46  5.02%  Properties
# 19  00083.HK    信和置業     11.480    782.59億  11.15  0.54  4.79%  Properties
# 20  00101.HK    恆隆地產     16.180    727.73億   8.99  0.53  4.64%  Properties
# 21  00688.HK  中國海外發展     26.950  2,952.70億   6.57  1.04  3.34%  Properties
# 22  00823.HK  領展房產基金     80.100  1,679.51億   8.38  0.90  3.39%  Properties
# 23  01109.HK    華潤置地     35.300  2,446.62億   8.86  1.55  3.42%  Properties
# 24  01113.HK    長實集團     52.050  1,922.41億   4.80  0.59  3.65%  Properties
# 25  01997.HK   九龍倉置業     43.300  1,314.69億   7.29  0.60  4.85%  Properties
# 26  02007.HK     碧桂園     11.200  2,446.60億   6.11  1.76  4.97%  Properties

# %%
it.useless("CI").indices()
# Out:
# Previous    14,781.30
# Open        14,897.09
# Instant     14,844.70
# Name: Commerce_and_Industry_Sub-index, dtype: object

# %%
it.useless("CI").stocks()
# Out:
#         Code      Name Last_price  Market_Cap    P/E    P/B   Yield  \
# 27  00001.HK        長和     71.000   2,737.93億   7.02   0.61   4.47%
# 28  00019.HK   太古股份公司Ａ     70.900     641.79億   4.50   0.39   4.23%
# 29  00027.HK      銀河娛樂     52.000   2,253.13億  16.62   3.61   1.83%
# 30  00066.HK      港鐵公司     43.900   2,703.21億  16.63   1.49   2.73%
# 31  00151.HK      中國旺旺      6.700     831.82億  20.55   4.66   4.01%
# 32  00175.HK      吉利汽車     14.800   1,353.51億   9.29   2.60   2.37%
# 33  00267.HK      中信股份      9.870   2,871.21億   5.71   0.51   4.15%
# 34  00288.HK      萬洲國際      8.150   1,199.42億  16.18   1.97   2.45%
# 35  00386.HK  中國石油化工股份      4.410   1,125.14億   7.61   0.65  10.84%
# 36  00669.HK      創科實業     60.000   1,097.99億  25.39   4.58   1.47%
# 37  00700.HK      騰訊控股    333.000  31,809.04億  35.09   8.61   0.30%
# 38  00762.HK      中國聯通      6.700   2,050.07億  17.83   0.57   2.28%
# 39  00857.HK    中國石油股份      3.600     759.56億  10.90   0.48   5.66%
# ...

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
import fed.HSI.historic as ht

# %%
ht.historic(["0001.HK","0005.HK"]).getprices()
# Out:
#               0001.HK    0005.HK
# Date
# 2018-12-03  78.868011  63.959579
# 2018-12-04  78.915924  63.865807
# 2018-12-05  77.286819  62.177731
# 2018-12-06  75.561874  60.911655
# 2018-12-07  75.226479  59.739380
# ...               ...        ...
# 2019-11-26  72.199997  58.799999
# 2019-11-27  71.750000  58.950001
# 2019-11-28  72.400002  58.799999
# 2019-11-29  71.099998  58.099998
# 2019-12-02  71.000000  58.400002
#
# [246 rows x 2 columns]

# %%
ht.historic("0001.HK").plotprices()

# %%
ht.historic("0001.HK").getreturns()
# Out:
# 2018-12-04    0.000608
# 2018-12-05   -0.020644
# 2018-12-06   -0.022319
# 2018-12-07   -0.004439
# 2018-12-10   -0.034395
#                 ...
# 2019-11-26    0.004871
# 2019-11-27   -0.006233
# 2019-11-28    0.009059
# 2019-11-29   -0.017956
# 2019-12-02   -0.001406
# Length: 245, dtype: float64

# %%
ht.historic("0001.HK").getlogreturns()
# Out:
# 2018-12-04    0.000607
# 2018-12-05   -0.020860
# 2018-12-06   -0.022572
# 2018-12-07   -0.004449
# 2018-12-10   -0.035000
#                 ...
# 2019-11-26    0.004859
# 2019-11-27   -0.006252
# 2019-11-28    0.009018
# 2019-11-29   -0.018119
# 2019-12-02   -0.001407
# Length: 245, dtype: float64

# %%
ht.historic("0001.HK").plotreturns()

# %%
ht.historic("0001.HK").plotreturns(log=True)

# %% [markdown]
# ***

# %%
ht.historic(["0001.HK","0005.HK"]).getprices()
# Out:
#               0001.HK    0005.HK
# Date
# 2018-12-03  78.868011  63.959579
# 2018-12-04  78.915924  63.865807
# 2018-12-05  77.286819  62.177731
# 2018-12-06  75.561874  60.911655
# 2018-12-07  75.226479  59.739380
# ...               ...        ...
# 2019-11-26  72.199997  58.799999
# 2019-11-27  71.750000  58.950001
# 2019-11-28  72.400002  58.799999
# 2019-11-29  71.099998  58.099998
# 2019-12-02  71.000000  58.400002
#
# [246 rows x 2 columns]

# %%
ht.historic(["0001.HK","0005.HK"]).plotprices()

# %%
ht.historic(["0001.HK","0005.HK"]).getreturns()
# Out:
#              0001.HK   0005.HK
# 2018-12-04  0.000608 -0.001466
# 2018-12-05 -0.020644 -0.026432
# 2018-12-06 -0.022319 -0.020362
# 2018-12-07 -0.004439 -0.019246
# 2018-12-10 -0.034395  0.000785
# ...              ...       ...
# 2019-11-26  0.004871 -0.003390
# 2019-11-27 -0.006233  0.002551
# 2019-11-28  0.009059 -0.002545
# 2019-11-29 -0.017956 -0.011905
# 2019-12-02 -0.001406  0.005164
#
# [245 rows x 2 columns]

# %%
ht.historic(["0001.HK","0005.HK"]).getlogreturns()
# Out:
#              0001.HK   0005.HK
# 2018-12-04  0.000607 -0.001467
# 2018-12-05 -0.020860 -0.026787
# 2018-12-06 -0.022572 -0.020572
# 2018-12-07 -0.004449 -0.019433
# 2018-12-10 -0.035000  0.000785
# ...              ...       ...
# 2019-11-26  0.004859 -0.003396
# 2019-11-27 -0.006252  0.002548
# 2019-11-28  0.009018 -0.002548
# 2019-11-29 -0.018119 -0.011976
# 2019-12-02 -0.001407  0.005150
#
# [245 rows x 2 columns]

# %%
ht.historic(["0001.HK","0005.HK"]).plotreturns()

# %%
ht.historic(["0001.HK","0005.HK"]).plotreturns(log=True)
